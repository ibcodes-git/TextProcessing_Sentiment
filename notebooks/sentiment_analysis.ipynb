# %%
sentiment_analysis.ipynb
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 sentiment_analysis.ipynb
#
# NameError: name 'sentiment_analysis' is not defined

# %%
import os
os.getcwd()

# %%
import pandas as pd
import sklearn
import nltk
import matplotlib.pyplot as plt
import seaborn as sns

print("Environment ready!")
# Out:
# Environment ready!
# First 10 stopwords: ['a', 'about', 'above', 'after', 'again', 'against', 'all', 'am', 'an', 'and']

# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, classification_report

import matplotlib.pyplot as plt
import seaborn as sns

print("Libraries loaded successfully")
# Out:
# Libraries loaded successfully

# %%
train_df = pd.read_csv("../data/Train.csv")
test_df = pd.read_csv("../data/Test.csv")

print("Train shape:", train_df.shape)
print("Test shape:", test_df.shape)

train_df.head()
# Out:
# Train shape: (40000, 2)
# Test shape: (5000, 2)
#                                                 text  label
# 0  I grew up (b. 1965) watching and loving the Th...      0
# 1  When I put this movie in my DVD player, and sa...      0
# 2  Why do people who do not know what a particula...      0
# 3  Even though I have great interest in Biblical ...      0
# 4  Im a die hard Dads Army fan and nothing will e...      1

# %%
x_train = train_df['text']
y_train = train_df['label']

x_test = test_df['text']
y_test = test_df['label']

# %%
vectorizer = TfidfVectorizer(
    lowercase=True,
    max_features=20000,
)

x_train_vec = vectorizer.fit_transform(x_train)
x_test_vec = vectorizer.transform(x_test)

model = LogisticRegression(max_iter=1000)
model.fit(x_train_vec, y_train)

y_pred = model.predict(x_test_vec)

# %%
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall= recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)

print("The test results are:")
print("Accuracy:", accuracy)
print("Precision:", precision)
print("Recall:", recall)
print("F1-score:", f1)

print(classification_report(y_test, y_pred))
# Out:
# The test results are:
# Accuracy: 0.8954
# Precision: 0.887109375
# Recall: 0.9065868263473054
# F1-score: 0.8967423494570582
#               precision    recall  f1-score   support
#
#            0       0.90      0.88      0.89      2495
#            1       0.89      0.91      0.90      2505
#
#     accuracy                           0.90      5000
#    macro avg       0.90      0.90      0.90      5000
# weighted avg       0.90      0.90      0.90      5000

# %%
from stop_words import get_stop_words

print("First 10 stopwords:", get_stop_words('english')[:10])

stop_words = get_stop_words('english')
len(stop_words)
# Out:
# First 10 stopwords: ['a', 'about', 'above', 'after', 'again', 'against', 'all', 'am', 'an', 'and']
# 174

# %%
vectorizer_sw = TfidfVectorizer(
    lowercase=True,
    stop_words='english',
    max_features=20000,
)
x_train_vec = vectorizer_sw.fit_transform(x_train)
y_train_vec = vectorizer_sw.transform(x_test)

# %%
model_sw = LogisticRegression(max_iter=1000)
model_sw.fit(x_train_vec, y_train)

y_pred_sw = model_sw.predict(x_test_vec)

# %%
accuracy_sw = accuracy_score(y_test, y_pred_sw)
precision_sw = precision_score(y_test, y_pred_sw)
recall_sw = recall_score(y_test, y_pred_sw)
f1_sw = f1_score(y_test, y_pred_sw)

print("The test results are:")
print("Accuracy:", accuracy_sw)
print("Precision:", precision_sw)
print("Recall:", recall_sw)
print("F1-score:", f1_sw)

print(classification_report(y_test, y_pred_sw))
# Out:
# The test results are:
# Accuracy: 0.8954
# Precision: 0.887109375
# Recall: 0.9065868263473054
# F1-score: 0.8967423494570582
#               precision    recall  f1-score   support
#
#            0       0.90      0.88      0.89      2495
#            1       0.89      0.91      0.90      2505
#
#     accuracy                           0.90      5000
#    macro avg       0.90      0.90      0.90      5000
# weighted avg       0.90      0.90      0.90      5000
