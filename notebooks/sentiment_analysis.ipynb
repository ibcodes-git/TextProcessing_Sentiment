# %%
sentiment_analysis.ipynb

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\ASUS\\Desktop\\Intelligent Systems Projects\\TextProcessing_Sentiment'

# %%
import pandas as pd
import sklearn
import nltk
import matplotlib.pyplot as plt
import seaborn as sns
from stop_words import get_stop_words

print("Environment ready!")
# Out:
# ----------------------------------------------------------------
# ModuleNotFoundError            Traceback (most recent call last)
# Cell In[2], line 6
#       4 import matplotlib.pyplot as plt
#       5 import seaborn as sns
# ----> 6 from stop_words import get_stop_words
#       8 print("Environment ready!")
#
# ModuleNotFoundError: No module named 'stop_words'

# %%
import pandas as pd
import sklearn
import nltk
import matplotlib.pyplot as plt
import seaborn as sns
from stop_words import get_stop_words

print("Environment ready!")
print("First 10 stopwords:", get_stop_words('english')[:10])
# Out:
# Environment ready!
# First 10 stopwords: ['a', 'about', 'above', 'after', 'again', 'against', 'all', 'am', 'an', 'and']
